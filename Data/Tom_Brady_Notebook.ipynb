# %%
import pandas as pd

# %%
tb = pd.read_csv('./Tom_Brady.csv')

# %%
tb
# Out:
#       Rk  Year        Date  G#  Week  Age   Tm  Unnamed: 7  Opp   Result  ...  \
# 0      1  2000  2000-09-03   1     1   23  NWE         NaN  TAM  L 16-21  ...
# 1      2  2000  2000-09-11   2     2   23  NWE         0.0  NYJ  L 19-20  ...
# 2      3  2000  2000-09-17   3     3   23  NWE         NaN  MIN  L 13-21  ...
# 3      4  2000  2000-09-24   4     4   23  NWE         0.0  MIA   L 3-10  ...
# 4      5  2000  2000-10-01   5     5   23  NWE         0.0  DEN  W 28-19  ...
# ..   ...   ...         ...  ..   ...  ...  ...         ...  ...      ...  ...
# 351  352  2021  2022-01-02  16    17   44  TAM         0.0  NYJ  W 28-24  ...
# 352  353  2021  2022-01-09  17    18   44  TAM         NaN  CAR  W 41-17  ...
# 353  354  2022  2022-09-11   1     1   45  TAM         0.0  DAL   W 19-3  ...
# 354  355  2022  2022-09-18   2     2   45  TAM         0.0  NOR  W 20-10  ...
# 355  356  2022  2022-09-25   3     3   45  TAM         NaN  GNB  L 12-14  ...
#
# ...

# %%
tb['PPR'] = 0
tb['Opponent_Rank'] = 0

# %%
tb
# Out:
#       Rk  Year        Date  G#  Week  Age   Tm  Unnamed: 7  Opp   Result  ...  \
# 0      1  2000  2000-09-03   1     1   23  NWE         NaN  TAM  L 16-21  ...
# 1      2  2000  2000-09-11   2     2   23  NWE         0.0  NYJ  L 19-20  ...
# 2      3  2000  2000-09-17   3     3   23  NWE         NaN  MIN  L 13-21  ...
# 3      4  2000  2000-09-24   4     4   23  NWE         0.0  MIA   L 3-10  ...
# 4      5  2000  2000-10-01   5     5   23  NWE         0.0  DEN  W 28-19  ...
# ..   ...   ...         ...  ..   ...  ...  ...         ...  ...      ...  ...
# 351  352  2021  2022-01-02  16    17   44  TAM         0.0  NYJ  W 28-24  ...
# 352  353  2021  2022-01-09  17    18   44  TAM         NaN  CAR  W 41-17  ...
# 353  354  2022  2022-09-11   1     1   45  TAM         0.0  DAL   W 19-3  ...
# 354  355  2022  2022-09-18   2     2   45  TAM         0.0  NOR  W 20-10  ...
# 355  356  2022  2022-09-25   3     3   45  TAM         NaN  GNB  L 12-14  ...
#
# ...

# %%
defenses = pd.read_csv('./Defenses.csv')

# %%
defenses
# Out:
#      Year  RANK NAME  PTS  FPTS  SACKS  INT  TO  PTS.1  PLAYS  ...  RUSH YDS  \
# 0    2022     1  TAM    6    45     11    5   8     27    191  ...       238
# 1    2022     2  DEN    2    28      9    1   4     36    160  ...       244
# 2    2022     3  SFO    0    25      8    3   4     37    173  ...       236
# 3    2022     4  BUF    8    41     11    5   7     38    158  ...       173
# 4    2022     4  JAX    0    36      7    6   8     38    176  ...       165
# ..    ...   ...  ...  ...   ...    ...  ...  ..    ...    ...  ...       ...
# 187  2017    28  NYG   14  1224     27   13  19    388   1052  ...      1933
# 188  2017    28  WAS   12  1097     41   16  23    388   1045  ...      2146
# 189  2017    30  IND   10  1165     26   13  20    404   1026  ...      1929
# 190  2017    31  CLE    6  1132     34    7  13    410   1026  ...      1566
# 191  2017    32  HOU   26  1206     32   11  16    436    973  ...      1747
#
# ...

# %%
tb['Opponent_Rank'] =

# %%
for team in tb['Opp']:
    for year in tb['Year']:
        if year == defenses['Year']:
            tb['Opponent_Rank'] == defenses['RANK']
        else:
            continue
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-6418db62eb6f> in <module>
#       1 for team in tb['Opp']:
#       2     for year in tb['Year']:
# ----> 3         if year == defenses['Year']:
#       4             tb['Opponent_Rank'] == defenses['RANK']
#       5         else:
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1327
#    1328     def __nonzero__(self):
# -> 1329         raise ValueError(
#    1330             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1331             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
