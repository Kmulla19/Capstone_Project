# %% [markdown]
# # Each Players Games For The Past Few Years

# %%
import pandas as pd

# %%
df = pd.read_csv('./2021_2022_PPR.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5843 entries, 0 to 5842
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Player             5843 non-null   object
#  1   PPR                5843 non-null   float64
#  2   Day                5843 non-null   object
#  3   G#                 5843 non-null   int64
#  4   Week               5843 non-null   int64
#  5   Season             5843 non-null   int64
#  6   Date               5843 non-null   object
#  7   Age                5843 non-null   object
#  8   Team               5843 non-null   object
#  9   Unnamed: 9         2902 non-null   object
#  10  Opp                5843 non-null   object
#  11  Result             5843 non-null   object
#  12  FantPt             5843 non-null   float64
#  13  PPR.1              5843 non-null   float64
#  14  DKPt               5843 non-null   float64
#  15  FDPt               5843 non-null   float64
#  16  Pos.               5843 non-null   object
#  17  Draft              4408 non-null   object
#  18  Player-additional  5843 non-null   object
# dtypes: float64(5), int64(3), object(11)
# memory usage: 867.4+ KB

# %%
df.head()
# Out:
#             Player    PPR  Day  G#  Week  Season        Date     Age Team  \
# 0     Amari Cooper  38.90  Thu   1     1    2021  2021-09-09  27-084  DAL
# 1      Tyreek Hill  37.10  Sun   1     1    2021  2021-09-12  27-195  KAN
# 2     Kyler Murray  33.56  Sun   1     1    2021  2021-09-12  24-036  ARI
# 3  Patrick Mahomes  33.28  Sun   1     1    2021  2021-09-12  25-360  KAN
# 4     Deebo Samuel  31.90  Sun   1     1    2021  2021-09-12  25-240  SFO
#
#   Unnamed: 9  Opp   Result  FantPt  PPR.1  DKPt  FDPt Pos.  Draft  \
# 0          @  TAM  L 29-31   25.90  38.90  41.9  32.4   WR    1-4
# 1        NaN  CLE  W 33-29   26.10  37.10  40.1  31.6   WR  5-165
# 2          @  TEN  W 38-13   33.56  33.56  34.6  34.6   QB    1-1
# 3        NaN  CLE  W 33-29   33.28  33.28  36.3  33.3   QB   1-10
# 4          @  DET  W 41-33   22.90  31.90  35.9  27.4   WR   2-36
#
#   Player-additional
# 0          CoopAm00
# 1          HillTy00
# 2          MurrKy00
# 3          MahoPa00
# 4          SamuDe00

# %% [markdown]
# #scraping for games
# url = 'https://www.pro-football-reference.com/players/B/BradTo00/gamelog/'
# TB_2021 = pd.read_html(url)[0]

# %%
TB_2021
# Out:
#     Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                     Rk               Year               Date
# 0                    1               2000         2000-09-03
# 1                    2               2000         2000-09-11
# 2                    3               2000         2000-09-17
# 3                    4               2000         2000-09-24
# 4                    5               2000         2000-10-01
# ..                 ...                ...                ...
# 374                 Rk               Year               Date
# 375                354               2022         2022-09-11
# 376                355               2022         2022-09-18
# 377                356               2022         2022-09-25
# 378                NaN                NaN          321 Games
#
#     Unnamed: 3_level_0 Unnamed: 4_level_0 Unnamed: 5_level_0  \
#                     G#               Week                Age
# 0                    1                  1                NaN
# 1                    2                  2                NaN
# 2                    3                  3                NaN
# 3                    4                  4                NaN
# 4                    5                  5                NaN
# ..                 ...                ...                ...
# 374                 G#               Week                Age
# 375                  1                  1             45.039
# 376                  2                  2             45.046
# 377                  3                  3             45.053
# 378                NaN                NaN                NaN
#
#     Unnamed: 6_level_0 Unnamed: 7_level_0 Unnamed: 8_level_0  \
#                     Tm Unnamed: 7_level_1                Opp
# 0                  NWE                NaN                TAM
# 1                  NWE                  @                NYJ
# 2                  NWE                NaN                MIN
# 3                  NWE                  @                MIA
# 4                  NWE                  @                DEN
# ..                 ...                ...                ...
# 374                 Tm                NaN                Opp
# 375                TAM                  @                DAL
# 376                TAM                  @                NOR
# 377                TAM                NaN                GNB
# 378                NaN                NaN                NaN
#
#     Unnamed: 9_level_0  ...   Punting                     Off. Snaps  \
#                 Result  ...       Yds       Y/P      Blck        Num
# 0              L 16-21  ...  Inactive  Inactive  Inactive   Inactive
# 1              L 19-20  ...  Inactive  Inactive  Inactive   Inactive
# 2              L 13-21  ...  Inactive  Inactive  Inactive   Inactive
# 3               L 3-10  ...  Inactive  Inactive  Inactive   Inactive
# 4              W 28-19  ...  Inactive  Inactive  Inactive   Inactive
# ..                 ...  ...       ...       ...       ...        ...
# 374             Result  ...       Yds       Y/P      Blck        Num
# 375             W 19-3  ...         0       NaN         0         62
# 376            W 20-10  ...         0       NaN         0         67
# 377            L 12-14  ...         0       NaN         0         65
# 378           245-76-0  ...        68     34.00         0        NaN
#
#               Def. Snaps            ST Snaps           Unnamed: 51_level_0
#           Pct        Num       Pct       Num       Pct              Status
# 0    Inactive   Inactive  Inactive  Inactive  Inactive            Inactive
# 1    Inactive   Inactive  Inactive  Inactive  Inactive            Inactive
# 2    Inactive   Inactive  Inactive  Inactive  Inactive            Inactive
# 3    Inactive   Inactive  Inactive  Inactive  Inactive            Inactive
# 4    Inactive   Inactive  Inactive  Inactive  Inactive            Inactive
# ..        ...        ...       ...       ...       ...                 ...
# 374       Pct        Num       Pct       Num       Pct              Status
# 375      100%          0        0%         0        0%                 NaN
# 376      100%          0        0%         0        0%                 NaN
# 377      100%          0        0%         0        0%                 NaN
# 378       NaN        NaN       NaN       NaN       NaN                 NaN
#
# [379 rows x 52 columns]

# %%
#Filters to pull a specific player

#player_filter = df.Player = ''
# EX:
player_filter = df[df.Player == 'Amari Cooper']

# %%
player_filter
# Out:
#             Player   PPR  Day  G#  Week  Season        Date     Age Team  \
# 0     Amari Cooper  38.9  Thu   1     1    2021  2021-09-09  27-084  DAL
# 523   Amari Cooper   5.4  Sun   2     2    2021  2021-09-19  27-094  DAL
# 846   Amari Cooper   5.6  Mon   3     3    2021  2021-09-27  27-102  DAL
# 1056  Amari Cooper  15.9  Sun   4     4    2021  2021-10-03  27-108  DAL
# 1383  Amari Cooper  15.0  Sun   5     5    2021  2021-10-10  27-115  DAL
# 1748  Amari Cooper  10.5  Sun   6     6    2021  2021-10-17  27-122  DAL
# 2211  Amari Cooper  26.2  Sun   7     8    2021  2021-10-31  27-136  DAL
# 2691  Amari Cooper   5.7  Sun   8     9    2021  2021-11-07  27-143  DAL
# 2915  Amari Cooper   9.1  Sun   9    10    2021  2021-11-14  27-150  DAL
# 3879  Amari Cooper   6.1  Thu  12    13    2021  2021-12-02  27-168  DAL
# 4060  Amari Cooper  16.1  Sun  13    14    2021  2021-12-12  27-178  DAL
# 4531  Amari Cooper   2.8  Sun  14    15    2021  2021-12-19  27-185  DAL
# 4624  Amari Cooper  21.5  Sun  15    16    2021  2021-12-26  27-192  DAL
# 5032  Amari Cooper  10.8  Sun  16    17    2021  2022-01-02  27-199  DAL
# 5461  Amari Cooper   4.7  Sun   1     1    2022  2022-09-11  28-086  CLE
# 5566  Amari Cooper  25.1  Sun   2     2    2022  2022-09-18  28-093  CLE
#
#      Unnamed: 9  Opp        Result  FantPt  PPR.1  DKPt  FDPt Pos. Draft  \
# 0             @  TAM       L 29-31    25.9   38.9  41.9  32.4   WR   1-4
# 523           @  LAC       W 20-17     2.4    5.4   5.4   3.9   WR   1-4
# 846         NaN  PHI       W 41-21     2.6    5.6   5.6   4.1   WR   1-4
# 1056        NaN  CAR       W 36-28    12.9   15.9  15.9  14.4   WR   1-4
# 1383        NaN  NYG       W 44-20    12.0   15.0  15.0  13.5   WR   1-4
# 1748          @  NWE  W 35-29 (OT)     5.5   10.5  10.5   8.0   WR   1-4
# 2211          @  MIN       W 20-16    18.2   26.2  29.2  22.2   WR   1-4
# 2691        NaN  DEN       L 16-30     3.7    5.7   5.7   4.7   WR   1-4
# 2915        NaN  ATL        W 43-3     5.1    9.1   9.1   7.1   WR   1-4
# 3879          @  NOR       W 27-17     4.1    6.1   6.1   5.1   WR   1-4
# 4060          @  WAS       W 27-20    11.1   16.1  16.1  13.6   WR   1-4
# 4531          @  NYG        W 21-6     0.8    2.8   2.8   1.8   WR   1-4
# 4624        NaN  WAS       W 56-14    14.5   21.5  21.5  18.0   WR   1-4
# 5032        NaN  ARI       L 22-25     7.8   10.8  10.8   9.3   WR   1-4
# 5461          @  CAR       W 26-24     1.7    4.7   4.7   3.2   WR   1-4
# 5566        NaN  NYJ       L 30-31    16.1   25.1  28.1  20.6   WR   1-4
#
#      Player-additional
# 0             CoopAm00
# 523           CoopAm00
# 846           CoopAm00
# 1056          CoopAm00
# 1383          CoopAm00
# 1748          CoopAm00
# 2211          CoopAm00
# 2691          CoopAm00
# 2915          CoopAm00
# 3879          CoopAm00
# 4060          CoopAm00
# 4531          CoopAm00
# 4624          CoopAm00
# 5032          CoopAm00
# 5461          CoopAm00
# 5566          CoopAm00

# %%
df['Home'] = df['Unnamed: 9'].apply(lambda x: 0 if x == '@' else 1)

# %%
df.head()
# Out:
#             Player    PPR  Day  G#  Week  Season        Date     Age Team  \
# 0     Amari Cooper  38.90  Thu   1     1    2021  2021-09-09  27-084  DAL
# 1      Tyreek Hill  37.10  Sun   1     1    2021  2021-09-12  27-195  KAN
# 2     Kyler Murray  33.56  Sun   1     1    2021  2021-09-12  24-036  ARI
# 3  Patrick Mahomes  33.28  Sun   1     1    2021  2021-09-12  25-360  KAN
# 4     Deebo Samuel  31.90  Sun   1     1    2021  2021-09-12  25-240  SFO
#
#   Unnamed: 9  Opp   Result  FantPt  PPR.1  DKPt  FDPt Pos.  Draft  \
# 0          @  TAM  L 29-31   25.90  38.90  41.9  32.4   WR    1-4
# 1        NaN  CLE  W 33-29   26.10  37.10  40.1  31.6   WR  5-165
# 2          @  TEN  W 38-13   33.56  33.56  34.6  34.6   QB    1-1
# 3        NaN  CLE  W 33-29   33.28  33.28  36.3  33.3   QB   1-10
# 4          @  DET  W 41-33   22.90  31.90  35.9  27.4   WR   2-36
#
#   Player-additional  Home
# 0          CoopAm00     0
# 1          HillTy00     1
# 2          MurrKy00     0
# 3          MahoPa00     1
# 4          SamuDe00     0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5843 entries, 0 to 5842
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Player             5843 non-null   object
#  1   PPR                5843 non-null   float64
#  2   Day                5843 non-null   object
#  3   G#                 5843 non-null   int64
#  4   Week               5843 non-null   int64
#  5   Season             5843 non-null   int64
#  6   Date               5843 non-null   object
#  7   Age                5843 non-null   object
#  8   Team               5843 non-null   object
#  9   Unnamed: 9         2902 non-null   object
#  10  Opp                5843 non-null   object
#  11  Result             5843 non-null   object
#  12  FantPt             5843 non-null   float64
#  13  PPR.1              5843 non-null   float64
#  14  DKPt               5843 non-null   float64
#  15  FDPt               5843 non-null   float64
#  16  Pos.               5843 non-null   object
#  17  Draft              4408 non-null   object
#  18  Player-additional  5843 non-null   object
#  19  Home               5843 non-null   int64
# dtypes: float64(5), int64(4), object(11)
# memory usage: 913.1+ KB

# %%
df['Unnamed: 9'].value_counts()
# Out:
# @    2902
# Name: Unnamed: 9, dtype: int64

# %%
df.head()
# Out:
#             Player    PPR  Day  G#  Week  Season        Date     Age Team  \
# 0     Amari Cooper  38.90  Thu   1     1    2021  2021-09-09  27-084  DAL
# 1      Tyreek Hill  37.10  Sun   1     1    2021  2021-09-12  27-195  KAN
# 2     Kyler Murray  33.56  Sun   1     1    2021  2021-09-12  24-036  ARI
# 3  Patrick Mahomes  33.28  Sun   1     1    2021  2021-09-12  25-360  KAN
# 4     Deebo Samuel  31.90  Sun   1     1    2021  2021-09-12  25-240  SFO
#
#   Unnamed: 9  Opp   Result  FantPt  PPR.1  DKPt  FDPt Pos.  Draft  \
# 0          @  TAM  L 29-31   25.90  38.90  41.9  32.4   WR    1-4
# 1        NaN  CLE  W 33-29   26.10  37.10  40.1  31.6   WR  5-165
# 2          @  TEN  W 38-13   33.56  33.56  34.6  34.6   QB    1-1
# 3        NaN  CLE  W 33-29   33.28  33.28  36.3  33.3   QB   1-10
# 4          @  DET  W 41-33   22.90  31.90  35.9  27.4   WR   2-36
#
#   Player-additional  Home
# 0          CoopAm00     0
# 1          HillTy00     1
# 2          MurrKy00     0
# 3          MahoPa00     1
# 4          SamuDe00     0

# %%
df.Team.value_counts().sort_index(ascending=True)
# Out:
# ARI    175
# ATL    186
# BAL    180
# BUF    181
# CAR    173
# CHI    168
# CIN    173
# CLE    182
# DAL    179
# DEN    173
# DET    173
# GNB    188
# HOU    191
# IND    183
# JAX    178
# KAN    206
# LAC    200
# LAR    162
# LVR    188
# MIA    199
# MIN    174
# NOR    184
# NWE    192
# NYG    183
# NYJ    191
# PHI    170
# PIT    175
# SEA    180
# SFO    180
# TAM    191
# TEN    196
# WAS    189
# Name: Team, dtype: int64

# %%
#Domed Stadiums
Dome_Dict = {
    "ARI" : 1,
    "ATL" : 1,
    "DAL" : 1,
    "DET" : 1,
    "HOU" : 1,
    "IND" : 1,
    "LAC" : 1,
    "LAR" : 1,
    "LVR" : 1,
    "MIN" : 1,
    "NOR" : 1,
}

# %%
#Dome Game
df['Dome_Home'] = df['Team'].apply(lambda x: 1 if x in Dome_Dict.keys() else 0)
df['Dome_Away'] = df['Opp'].apply(lambda x: 1 if x in Dome_Dict.keys() else 0)

# %%
df.head()
# Out:
#             Player    PPR  Day  G#  Week  Season        Date     Age Team  \
# 0     Amari Cooper  38.90  Thu   1     1    2021  2021-09-09  27-084  DAL
# 1      Tyreek Hill  37.10  Sun   1     1    2021  2021-09-12  27-195  KAN
# 2     Kyler Murray  33.56  Sun   1     1    2021  2021-09-12  24-036  ARI
# 3  Patrick Mahomes  33.28  Sun   1     1    2021  2021-09-12  25-360  KAN
# 4     Deebo Samuel  31.90  Sun   1     1    2021  2021-09-12  25-240  SFO
#
#   Unnamed: 9  ... FantPt  PPR.1  DKPt  FDPt  Pos.  Draft Player-additional  \
# 0          @  ...  25.90  38.90  41.9  32.4    WR    1-4          CoopAm00
# 1        NaN  ...  26.10  37.10  40.1  31.6    WR  5-165          HillTy00
# 2          @  ...  33.56  33.56  34.6  34.6    QB    1-1          MurrKy00
# 3        NaN  ...  33.28  33.28  36.3  33.3    QB   1-10          MahoPa00
# 4          @  ...  22.90  31.90  35.9  27.4    WR   2-36          SamuDe00
#
#   Home Dome_Home  Dome_Away
# 0    0         1          0
# 1    1         0          0
# 2    0         1          0
# 3    1         0          0
# 4    0         0          1
#
# [5 rows x 22 columns]

# %%
df['Dome'] = df['Dome_Home'] + df['Dome_Away']

# %%
df.head()
# Out:
#             Player    PPR  Day  G#  Week  Season        Date     Age Team  \
# 0     Amari Cooper  38.90  Thu   1     1    2021  2021-09-09  27-084  DAL
# 1      Tyreek Hill  37.10  Sun   1     1    2021  2021-09-12  27-195  KAN
# 2     Kyler Murray  33.56  Sun   1     1    2021  2021-09-12  24-036  ARI
# 3  Patrick Mahomes  33.28  Sun   1     1    2021  2021-09-12  25-360  KAN
# 4     Deebo Samuel  31.90  Sun   1     1    2021  2021-09-12  25-240  SFO
#
#   Unnamed: 9  ...  PPR.1  DKPt  FDPt  Pos.  Draft  Player-additional Home  \
# 0          @  ...  38.90  41.9  32.4    WR    1-4           CoopAm00    0
# 1        NaN  ...  37.10  40.1  31.6    WR  5-165           HillTy00    1
# 2          @  ...  33.56  34.6  34.6    QB    1-1           MurrKy00    0
# 3        NaN  ...  33.28  36.3  33.3    QB   1-10           MahoPa00    1
# 4          @  ...  31.90  35.9  27.4    WR   2-36           SamuDe00    0
#
#   Dome_Home Dome_Away  Dome
# 0         1         0     1
# 1         0         0     0
# 2         1         0     1
# 3         0         0     0
# 4         0         1     1
#
# [5 rows x 23 columns]

# %%
#
Day
Date(Month)
Age
Team
Opp 
Home
Dome
Pos
Draft?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5843 entries, 0 to 5842
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Player             5843 non-null   object
#  1   PPR                5843 non-null   float64
#  2   Day                5843 non-null   object
#  3   G#                 5843 non-null   int64
#  4   Week               5843 non-null   int64
#  5   Season             5843 non-null   int64
#  6   Date               5843 non-null   object
#  7   Age                5843 non-null   object
#  8   Team               5843 non-null   object
#  9   Unnamed: 9         2902 non-null   object
#  10  Opp                5843 non-null   object
#  11  Result             5843 non-null   object
#  12  FantPt             5843 non-null   float64
#  13  PPR.1              5843 non-null   float64
#  14  DKPt               5843 non-null   float64
#  15  FDPt               5843 non-null   float64
#  16  Pos.               5843 non-null   object
#  17  Draft              4408 non-null   object
#  18  Player-additional  5843 non-null   object
#  19  Home               5843 non-null   int64
#  20  Dome               5843 non-null   int64
# dtypes: float64(5), int64(5), object(11)
# memory usage: 958.7+ KB

# %%
df['Player'].value_counts()
# Out:
# Kendrick Bourne     18
# Ezekiel Elliott     18
# Courtland Sutton    18
# Carson Wentz        18
# Joe Mixon           18
#                     ..
# Simi Fehoko          1
# Kyle Philips         1
# Nick Mullens         1
# Keith Kirkwood       1
# Pat Elflein          1
# Name: Player, Length: 739, dtype: int64

# %%
df.drop(['Dome_Home', 'Dome_Away'], axis=1, inplace=True)

# %%
df.head()
# Out:
#             Player    PPR  Day  G#  Week  Season        Date     Age Team  \
# 0     Amari Cooper  38.90  Thu   1     1    2021  2021-09-09  27-084  DAL
# 1      Tyreek Hill  37.10  Sun   1     1    2021  2021-09-12  27-195  KAN
# 2     Kyler Murray  33.56  Sun   1     1    2021  2021-09-12  24-036  ARI
# 3  Patrick Mahomes  33.28  Sun   1     1    2021  2021-09-12  25-360  KAN
# 4     Deebo Samuel  31.90  Sun   1     1    2021  2021-09-12  25-240  SFO
#
#   Unnamed: 9  ...   Result FantPt  PPR.1  DKPt  FDPt  Pos.  Draft  \
# 0          @  ...  L 29-31  25.90  38.90  41.9  32.4    WR    1-4
# 1        NaN  ...  W 33-29  26.10  37.10  40.1  31.6    WR  5-165
# 2          @  ...  W 38-13  33.56  33.56  34.6  34.6    QB    1-1
# 3        NaN  ...  W 33-29  33.28  33.28  36.3  33.3    QB   1-10
# 4          @  ...  W 41-33  22.90  31.90  35.9  27.4    WR   2-36
#
#   Player-additional Home  Dome
# 0          CoopAm00    0     1
# 1          HillTy00    1     0
# 2          MurrKy00    0     1
# 3          MahoPa00    1     0
# 4          SamuDe00    0     1
#
# [5 rows x 21 columns]

# %% [markdown]
# # Defense by rank that week

# %%
#level up by pass/run def or by player ranking that week

# %% [markdown]
# # Other Factors

# %%
#Home/Away
